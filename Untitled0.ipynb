# %% [markdown]
# Подключение библиотек

# %%
# !pip install phik -q
from phik.report import plot_correlation_matrix
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from phik import phik_matrix
from sklearn.linear_model import LogisticRegression, Ridge, LinearRegression
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score, RandomizedSearchCV
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.dummy import DummyClassifier
from sklearn.inspection import permutation_importance
from imblearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

from sklearn.preprocessing import (
    OneHotEncoder,
    OrdinalEncoder,
    StandardScaler,
    MinMaxScaler,
    LabelEncoder
)

from sklearn.metrics import (
    f1_score,
)
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import SMOTE
from sklearn.tree import DecisionTreeClassifier
from imblearn.over_sampling import ADASYN

# %%
RANDOM_STATE=42

# %% [markdown]
# Загрузка данных

# %%
df_train = pd.read_csv('/content/kaggle_startups_train_28062024.csv', sep=',', decimal='.')
df_test = pd.read_csv('/content/kaggle_startups_test_28062024.csv', sep=',', decimal='.')

# %%
df_train.head()
# Out:
#                      name                          category_list  \
# 0               Lunchgate        Online Reservations|Restaurants
# 1                 EarLens  Manufacturing|Medical|Medical Devices
# 2  Reviva Pharmaceuticals                          Biotechnology
# 3    Sancilio and Company                            Health Care
# 4     WireTough Cylinders                          Manufacturing
#
#    funding_total_usd     status country_code state_code       region  \
# 0           828626.0  operating          CHE         25       Zurich
# 1         42935019.0  operating          USA         CA  SF Bay Area
# 2         35456381.0  operating          USA         CA  SF Bay Area
# 3         22250000.0  operating          NaN        NaN          NaN
# 4                NaN  operating          USA         VA   VA - Other
#
#            city  funding_rounds  founded_at first_funding_at last_funding_at  \
# 0        Zürich               2  2009-10-17       2011-05-01      2014-12-01
# ...

# %%
df_test.head()
# Out:
#                      name                   category_list  funding_total_usd  \
# 0              Crystalsol                Clean Technology          2819200.0
# 1        JBI Fish & Wings                     Hospitality                NaN
# 2                COINPLUS                         Finance           428257.0
# 3  Imagine Communications  Software|Video|Video Streaming         34700000.0
# 4                   DNA13                        Software          4530000.0
#
#   country_code state_code            region              city  funding_rounds  \
# 0          NIC         17               NaN               NaN               1
# 1          USA         TN        TN - Other          Humboldt               1
# 2          LUX          3  Esch-sur-alzette  Esch-sur-alzette               2
# 3          USA         CA         San Diego         San Diego               4
# 4          CAN         ON            Ottawa            Ottawa               1
#
# ...

# %%
df_test_name=df_test['name']

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52516 entries, 0 to 52515
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               52515 non-null  object
#  1   category_list      50051 non-null  object
#  2   funding_total_usd  42447 non-null  float64
#  3   status             52516 non-null  object
#  4   country_code       47014 non-null  object
#  5   state_code         45753 non-null  object
#  6   region             46157 non-null  object
#  7   city               46157 non-null  object
#  8   funding_rounds     52516 non-null  int64
#  9   founded_at         52516 non-null  object
#  10  first_funding_at   52516 non-null  object
#  11  last_funding_at    52516 non-null  object
#  12  closed_at          4917 non-null   object
# dtypes: float64(1), int64(1), object(11)
# memory usage: 5.2+ MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13125 entries, 0 to 13124
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   name               13125 non-null  object
#  1   category_list      12534 non-null  object
#  2   funding_total_usd  10547 non-null  float64
#  3   country_code       11743 non-null  object
#  4   state_code         11430 non-null  object
#  5   region             11536 non-null  object
#  6   city               11538 non-null  object
#  7   funding_rounds     13125 non-null  int64
#  8   first_funding_at   13125 non-null  object
#  9   last_funding_at    13125 non-null  object
#  10  lifetime           13125 non-null  int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 1.1+ MB

# %% [markdown]
# Предобработка данных

# %%
df_train.name = 'df_train'
df_test.name = 'df_test'

# %%
df_list = [df_train, df_test]

# %% [markdown]
# Поиск пропущенных значений

# %%
for df in df_list:
    print(f'Пропущенные значения {df.name}:\n{df.isna().sum()}')
    print('\n')
# Out:
# Пропущенные значения 0        df_train
# 1        df_train
# 2        df_train
# 3        df_train
# 4        df_train
#            ...
# 52511    df_train
# 52512    df_train
# 52513    df_train
# 52514    df_train
# 52515    df_train
# Name: name, Length: 52516, dtype: object:
# name                     0
# category_list         2465
# funding_total_usd    10069
# status                   0
# country_code          5502
# state_code            6763
# region                6359
# city                  6359
# funding_rounds           0
# founded_at               0
# first_funding_at         0
# last_funding_at          0
# closed_at            47599
# dtype: int64
#
#
# Пропущенные значения 0        df_test
# 1        df_test
# 2        df_test
# 3        df_test
# 4        df_test
#           ...
# 13120    df_test
# 13121    df_test
# 13122    df_test
# 13123    df_test
# 13124    df_test
# Name: name, Length: 13125, dtype: object:
# name                    0
# ...

# %%
missing_values = df_train[df_train['name'].isnull()]
missing_values
# Out:
# Empty DataFrame
# Columns: [name, category_list, funding_total_usd, status, country_code, state_code, region, city, funding_rounds, founded_at, first_funding_at, last_funding_at, closed_at]
# Index: []

# %% [markdown]
# Пропуск в столбце 'name' не нужно заполнять или удалять, скорее всего мы не будем использовать этот столбец в обучении модели, потому что название стартапа не очень сильно влияет на его статус и будет вносить лишний шум

# %%
df_train.closed_at.fillna(pd.to_datetime('2018-01-01'), inplace=True)

# %%
missing_values = df_train[df_train['closed_at'].isnull()]
missing_values
# Out:
# Empty DataFrame
# Columns: [name, category_list, funding_total_usd, status, country_code, state_code, region, city, funding_rounds, founded_at, first_funding_at, last_funding_at, closed_at]
# Index: []

# %%
df_train['founded_at'] = pd.to_datetime(df_train['founded_at'])
df_train['closed_at'] = pd.to_datetime(df_train['closed_at'])

# %%
df_train['lifetime'] = (df_train.closed_at-df_train.founded_at).dt.days

# %%
df_train = df_train.drop(['founded_at', 'closed_at'], axis=1)

# %%
df_train['category_list'] = df_train['category_list'].fillna(value='unknown')

# %%
df_train['funding_total_usd'] = df_train['funding_total_usd'].fillna(df_train['funding_total_usd'].median())

# %%
df_train_state_code = df_train['state_code']
df_train_region = df_train['region']
df_train = df_train.drop(['state_code', 'region'], axis=1)

# %%
df_train['avg_funding'] = df_train['funding_total_usd'] / df_train['funding_rounds']

# %%
df_train['first_funding_at'] = pd.to_datetime(df_train['first_funding_at'])
df_train['last_funding_at'] = pd.to_datetime(df_train['last_funding_at'])
df_train['funding_interval'] = (df_train['last_funding_at'] - df_train['first_funding_at']).dt.days

# %%
df_train = df_train.drop(['first_funding_at', 'last_funding_at'], axis=1)

# %%
for df in df_list:
    print(f'Явных дубликатов в "{df.name}": {df.duplicated().sum()}')
# Out:
# Явных дубликатов в "0        df_train
# 1        df_train
# 2        df_train
# 3        df_train
# 4        df_train
#            ...
# 52511    df_train
# 52512    df_train
# 52513    df_train
# 52514    df_train
# 52515    df_train
# Name: name, Length: 52516, dtype: object": 10
# Явных дубликатов в "0        df_test
# 1        df_test
# 2        df_test
# 3        df_test
# 4        df_test
#           ...
# 13120    df_test
# 13121    df_test
# 13122    df_test
# 13123    df_test
# 13124    df_test
# Name: name, Length: 13125, dtype: object": 1

# %%
df_train = df_train.drop_duplicates()

# %%
def num_func(data):
    fig, axes = plt.subplots(1, 2, figsize=(12, 5))
    plt.subplot(1,2,1)
    plt.hist(data, bins=30, ec='black', color='y', alpha=0.5)
    plt.title('Распределение', size=15)
    plt.ylabel('Частота', size=12)
    plt.grid(linestyle='dashed')
    plt.subplot(1,2,2)
    plt.boxplot(data, vert=False)
    plt.title('Ящик с усами', size=15)
    plt.grid(linestyle='dashed')
    plt.show()
    print('Описательная статистика:')
    print(data.describe())

# %%
df_train = df_train.drop(['name'], axis=1)

# %%
df_target = df_train['status']
df_train = df_train.drop(['status'], axis=1)

# %%
df_train.head()
# Out:
#                            category_list  funding_total_usd country_code  \
# 0        Online Reservations|Restaurants           828626.0          CHE
# 1  Manufacturing|Medical|Medical Devices         42935019.0          USA
# 2                          Biotechnology         35456381.0          USA
# 3                            Health Care         22250000.0          NaN
# 4                          Manufacturing          2000000.0          USA
#
#            city  funding_rounds  lifetime   avg_funding  funding_interval
# 0        Zürich               2      2998  4.143130e+05              1310
# 1  Redwood City               4      4748  1.073375e+07              1393
# 2      San Jose               3      4383  1.181879e+07               681
# 3           NaN               3      5114  7.416667e+06              1051
# 4       Bristol               1      2791  2.000000e+06                 0

# %%
df_train['country_code'] = df_train['country_code'].fillna(value='unknown')
df_train['city'] = df_train['city'].fillna(value='unknown')

# %%
df_train_num = df_train[df_train.select_dtypes(include='number').columns]
for i in df_train_num:
    print(f'Столбец "{i}"')
    num_func(df_train_num[i])
    plt.show()
    print('\n')
# Out:
# Столбец "funding_total_usd"
# Описательная статистика:
# count    5.232800e+04
# mean     1.518010e+07
# std      1.686468e+08
# min      1.000000e+00
# 25%      5.250000e+05
# 50%      2.000000e+06
# 75%      6.847190e+06
# max      3.007950e+10
# Name: funding_total_usd, dtype: float64
#
#
# Столбец "funding_rounds"
# Описательная статистика:
# count    52328.000000
# mean         1.743331
# std          1.376271
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max         19.000000
# Name: funding_rounds, dtype: float64
#
#
# Столбец "lifetime"
# Описательная статистика:
# count    52328.000000
# mean      3145.204460
# std       2149.602109
# min         19.000000
# 25%       1743.000000
# 50%       2557.000000
# 75%       4018.000000
# max      17378.000000
# Name: lifetime, dtype: float64
#
#
# Столбец "avg_funding"
# Описательная статистика:
# count    5.232800e+04
# mean     7.591203e+06
# std      7.653494e+07
# ...

# %%
phik_overview = df_train.sample(1000).phik_matrix()
plot_correlation_matrix(phik_overview.values, x_labels=phik_overview.columns, y_labels=phik_overview.index,
                        vmin=0, vmax=1, color_map='Greens', title=r'correlation $\phi_K$', fontsize_factor=1,
                        figsize=(10,10))
plt.tight_layout()
# Out:
# interval columns not set, guessing: ['funding_total_usd', 'funding_rounds', 'lifetime', 'avg_funding', 'funding_interval']

# %%
df_target.value_counts(normalize=True).plot(kind='bar')
plt.title('Распределение классов целевого признака', size=14)
plt.xlabel('Показатель работы стартапа', size=12)
plt.ylabel('Частота встречаемости', size=12)
plt.xticks(rotation=0)
# Out:
# (array([0, 1]), [Text(0, 0, 'operating'), Text(1, 0, 'closed')])

# %%
class_counts = df_target.value_counts()
class_counts
# Out:
# status
# operating    47449
# closed        4879
# Name: count, dtype: int64

# %%
cat_value_one = 'operating'
cat_value_zero = 'closed'
def to_binary_func(value):
    if value == cat_value_one:
        return 1
    elif value == cat_value_zero:
        return 0

df_target = df_target.apply(to_binary_func)

# %%
df_train.head()
# Out:
#                            category_list  funding_total_usd country_code  \
# 0        Online Reservations|Restaurants           828626.0          CHE
# 1  Manufacturing|Medical|Medical Devices         42935019.0          USA
# 2                          Biotechnology         35456381.0          USA
# 3                            Health Care         22250000.0      unknown
# 4                          Manufacturing          2000000.0          USA
#
#            city  funding_rounds  lifetime   avg_funding  funding_interval
# 0        Zürich               2      2998  4.143130e+05              1310
# 1  Redwood City               4      4748  1.073375e+07              1393
# 2      San Jose               3      4383  1.181879e+07               681
# 3       unknown               3      5114  7.416667e+06              1051
# 4       Bristol               1      2791  2.000000e+06                 0

# %%
df_test.head()
# Out:
#       name                   category_list  funding_total_usd country_code  \
# 0  df_test                Clean Technology          2819200.0          NIC
# 1  df_test                     Hospitality                NaN          USA
# 2  df_test                         Finance           428257.0          LUX
# 3  df_test  Software|Video|Video Streaming         34700000.0          USA
# 4  df_test                        Software          4530000.0          CAN
#
#   state_code            region              city  funding_rounds  \
# 0         17               NaN               NaN               1
# 1         TN        TN - Other          Humboldt               1
# 2          3  Esch-sur-alzette  Esch-sur-alzette               2
# 3         CA         San Diego         San Diego               4
# 4         ON            Ottawa            Ottawa               1
#
#   first_funding_at last_funding_at  lifetime
# 0       2009-07-01      2009-07-01      3501
# ...

# %%
df_test = df_test.drop(['region', 'state_code'], axis=1)

# %%
df_test['funding_total_usd'] = df_test['funding_total_usd'].fillna(df_train['funding_total_usd'].median())
df_test['avg_funding'] = df_test['funding_total_usd'] / df_test['funding_rounds']
df_test['first_funding_at'] = pd.to_datetime(df_test['first_funding_at'])
df_test['last_funding_at'] = pd.to_datetime(df_test['last_funding_at'])
df_test['funding_interval'] = (df_test['last_funding_at'] - df_test['first_funding_at']).dt.days

# %%
df_test = df_test.drop(['name', 'first_funding_at', 'last_funding_at'],axis=1)
df_test['category_list'] = df_test['category_list'].fillna(value='unknown')
df_test['country_code'] = df_test['country_code'].fillna(value='unknown')
df_test['city'] = df_test['city'].fillna(value='unknown')

# %%
df_test.head()
# Out:
#                     category_list  funding_total_usd country_code  \
# 0                Clean Technology          2819200.0          NIC
# 1                     Hospitality          2000000.0          USA
# 2                         Finance           428257.0          LUX
# 3  Software|Video|Video Streaming         34700000.0          USA
# 4                        Software          4530000.0          CAN
#
#                city  funding_rounds  lifetime  avg_funding  funding_interval
# 0           unknown               1      3501    2819200.0                 0
# 1          Humboldt               1      2717    2000000.0                 0
# 2  Esch-sur-alzette               2      1295     214128.5               126
# 3         San Diego               4      4748    8675000.0              1935
# 4            Ottawa               1      6209    4530000.0                 0

# %%
df_train.head()
# Out:
#                            category_list  funding_total_usd country_code  \
# 0        Online Reservations|Restaurants           828626.0          CHE
# 1  Manufacturing|Medical|Medical Devices         42935019.0          USA
# 2                          Biotechnology         35456381.0          USA
# 3                            Health Care         22250000.0      unknown
# 4                          Manufacturing          2000000.0          USA
#
#            city  funding_rounds  lifetime   avg_funding  funding_interval
# 0        Zürich               2      2998  4.143130e+05              1310
# 1  Redwood City               4      4748  1.073375e+07              1393
# 2      San Jose               3      4383  1.181879e+07               681
# 3       unknown               3      5114  7.416667e+06              1051
# 4       Bristol               1      2791  2.000000e+06                 0

# %%
df_train = df_train.drop('city', axis=1)
df_test = df_test.drop('city', axis=1)

# %%
# Определение колонок
ohe_column = ['category_list', 'country_code']
num_column = ['funding_total_usd', 'funding_rounds', 'lifetime', 'avg_funding', 'funding_interval']

# Определение пайплайнов
ohe_pipe = Pipeline([
    ('ohe', OneHotEncoder(drop='first', handle_unknown='ignore', sparse_output=False))
])

# Препроцессор
data_preprocessor = ColumnTransformer(
    transformers=[
        ('ohe', ohe_pipe, ohe_column),
        ('num', MinMaxScaler(), num_column)
    ],
    remainder='passthrough'
)

# Окончательный пайплайн без SMOTE
pipe_final = Pipeline([
    ('preprocessor', data_preprocessor),
    ('SMOTE', SMOTE(random_state=RANDOM_STATE)),
    ('models', RandomForestClassifier(random_state=RANDOM_STATE))
])

# Параметры для RandomizedSearchCV
param_grid = [
    {
        'models': [LogisticRegression(
            random_state=RANDOM_STATE,
            solver='liblinear',
            penalty='l1',
            class_weight='balanced'
        )],
        'models__C': range(1, 5),
        'preprocessor__num': [StandardScaler(), MinMaxScaler()]
    },
    {
        'models': [SVC(
            random_state=RANDOM_STATE,
            kernel='linear',
            probability=True
        )],
        'models__C': range(1, 10),
        'preprocessor__num': [StandardScaler(), MinMaxScaler()]
    },
    {
        'models': [GradientBoostingClassifier(random_state=RANDOM_STATE)],
        'models__learning_rate': [0.01, 0.1, 0.2],
        'models__n_estimators': [100, 200, 300],
        'models__max_depth': [3, 4, 5],
        'preprocessor__num': [StandardScaler(), MinMaxScaler()]
    }
]

# RandomizedSearchCV
randomized_search = RandomizedSearchCV(
    pipe_final,
    param_distributions=param_grid,
    cv=5,
    scoring='f1',
    random_state=RANDOM_STATE,
    n_jobs=4
)

# Обучение модели
randomized_search.fit(df_train.head(1000), df_target.head(1000))

# Предсказание вероятностей
proba = randomized_search.predict_proba(df_test)
proba_one = proba[:, 1]

# Вывод результатов
print('Лучшая модель и её параметры:\n\n', randomized_search.best_estimator_)
print('\n')
print('Параметры лучшей модели:\n', randomized_search.best_params_)
print('\n')
print('Метрика лучшей модели на тренировочной выборке:', randomized_search.best_score_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# Лучшая модель и её параметры:
#
#  Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ohe',
#                                                   Pipeline(steps=[('ohe',
#                                                                    OneHotEncoder(drop='first',
#                                                                                  handle_unknown='ignore',
#                                                                                  sparse_output=False))]),
#                                                   ['category_list',
#                                                    'country_code']),
# ...

# %%
pd.DataFrame(randomized_search.cv_results_)[
    ['rank_test_score', 'param_models', 'mean_test_score','params']
].sort_values('rank_test_score')
# Out:
#    rank_test_score                                       param_models  \
# 7                1  GradientBoostingClassifier(learning_rate=0.2, ...
# 0                2  GradientBoostingClassifier(learning_rate=0.2, ...
# 5                3  GradientBoostingClassifier(learning_rate=0.2, ...
# 3                4  GradientBoostingClassifier(learning_rate=0.2, ...
# 2                5  SVC(kernel='linear', probability=True, random_...
# 4                6  SVC(kernel='linear', probability=True, random_...
# 6                7  SVC(kernel='linear', probability=True, random_...
# 1                8  LogisticRegression(class_weight='balanced', pe...
# 9                9  SVC(kernel='linear', probability=True, random_...
# 8               10  LogisticRegression(class_weight='balanced', pe...
#
#    mean_test_score                                             params
# 7         0.964077  {'preprocessor__num': StandardScaler(), 'model...
# ...

# %%
predictions = randomized_search.predict(df_test)
series_from_list = pd.Series(predictions)
df = pd.DataFrame([df_test_name, series_from_list]).T
df = df.rename(columns={'Unnamed 0': 'status'})
df['status'] = df['status'].replace({0: 'closed', 1: 'operating'})
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:202: UserWarning: Found unknown categories in columns [0, 1] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
df
# Out:
#                          name     status
# 0                  Crystalsol  operating
# 1            JBI Fish & Wings  operating
# 2                    COINPLUS  operating
# 3      Imagine Communications  operating
# 4                       DNA13  operating
# ...                       ...        ...
# 13120                   Jymob  operating
# 13121               GlobaTrek  operating
# 13122                Inkd.com  operating
# 13123                  AdWill  operating
# 13124             RingCentral  operating
#
# [13125 rows x 2 columns]

# %%
# @title status

from matplotlib import pyplot as plt
import seaborn as sns
df.groupby('status').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df=df.set_index('name')

# %%
df.to_csv('submit.csv')
